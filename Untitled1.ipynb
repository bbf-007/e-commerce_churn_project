# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn import datasets
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.decomposition import PCA, KernelPCA
from sklearn.datasets import make_circles
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.decomposition import NMF
from sklearn.decomposition import TruncatedSVD
from scipy.sparse import csr_matrix
# %matplotlib inline

# %%
df = pd.read_csv("ds2.csv")

# %%
df.head()

# %%
df['churn'] = [1 if value < 1 else 0 for value in df['return_frequency']]

# %%
df.describe()
# Out:
#               user_id             age    income_level    has_children  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean    500000.500000       49.003377   104994.565463        0.399426
# std     288675.278933       18.193959    54851.476652        0.489781
# min          1.000000       18.000000    10000.000000        0.000000
# 25%     250000.750000       33.000000    57466.000000        0.000000
# 50%     500000.500000       49.000000   105013.000000        0.000000
# 75%     750000.250000       65.000000   152497.000000        1.000000
# max    1000000.000000       80.000000   200000.000000        1.000000
#
#        household_size  weekly_purchases   monthly_spend  \
# count  1000000.000000    1000000.000000  1000000.000000
# mean         5.505323          9.993011     2498.775654
# std          2.873725          6.055124     1444.208674
# min          1.000000          0.000000        0.000000
# 25%          3.000000          5.000000     1249.000000
# 50%          6.000000         10.000000     2498.000000
# 75%          8.000000         15.000000     3750.000000
# max         10.000000         20.000000     5000.000000
#
#        cart_abandonment_rate  review_writing_frequency  average_order_value  \
# count         1000000.000000            1000000.000000       1000000.000000
# mean               40.212257                  3.450584           255.031632
# std                25.433343                  1.856725           141.708466
# min                 0.000000                  0.000000            10.000000
# 25%                18.000000                  2.000000           132.000000
# 50%                40.000000                  3.000000           255.000000
# 75%                62.000000                  5.000000           378.000000
# max                90.000000                  8.000000           500.000000
#
#        ...  cart_items_average  checkout_abandonments_per_month  \
# count  ...      1000000.000000                   1000000.000000
# mean   ...            5.494336                         4.997523
# std    ...            2.870467                         3.162831
# min    ...            1.000000                         0.000000
# 25%    ...            3.000000                         2.000000
# 50%    ...            5.000000                         5.000000
# 75%    ...            8.000000                         8.000000
# max    ...           10.000000                        10.000000
#
#        purchase_conversion_rate  app_usage_frequency  \
# count            1000000.000000       1000000.000000
# mean                  50.001442             3.498840
# std                   29.163437             2.291567
# min                    0.000000             0.000000
# 25%                   25.000000             1.000000
# 50%                   50.000000             3.000000
# 75%                   75.000000             6.000000
# max                  100.000000             7.000000
#
#        notification_response_rate  account_age_months  \
# count              1000000.000000      1000000.000000
# mean                    49.989012           12.509560
# std                     29.151948            6.922197
# min                      0.000000            1.000000
# 25%                     25.000000            7.000000
# 50%                     50.000000           13.000000
# 75%                     75.000000           19.000000
# max                    100.000000           24.000000
#
#        social_sharing_frequency  premium_subscription     return_rate  \
# count            1000000.000000        1000000.000000  1000000.000000
# mean                   3.593763              0.359415       50.004949
# std                    1.932566              0.479829       29.159616
# min                    0.000000              0.000000        0.000000
# 25%                    2.000000              0.000000       25.000000
# 50%                    4.000000              0.000000       50.000000
# 75%                    5.000000              1.000000       75.000000
# max                    8.000000              1.000000      100.000000
#
#                 churn
# count  1000000.000000
# mean         0.076803
# std          0.266279
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
#
# [8 rows x 46 columns]

# %%
categorical_cols = ['gender', 'country', 'urban_rural', 'employment_status', 'education_level',
                    'relationship_status', 'has_children', 'occupation', 'ethnicity',
                    'language_preference', 'device_type', 'preferred_payment_method', 
                    'loyalty_program_member', 'product_category_preference', 'shopping_time_of_day', 
                    'weekend_shopper', 'budgeting_style', 'health_conscious_shopping', 'premium_subscription']
#removed 'last_purchase_date' from categorical_cols

# %%
encoder = LabelEncoder()
for each_col in categorical_cols:
    df[each_col] = encoder.fit_transform(df[each_col])

# %%
df.head()
# Out:
#    user_id  age  gender  country  urban_rural  income_level  \
# 0        1   56       0        5            1         90860
# 1        2   69       1        7            1         35423
# 2        3   46       0        6            2         21467
# 3        4   32       1        2            2         41770
# 4        5   60       0        7            2        183882
#
#    employment_status  education_level  relationship_status  has_children  ...  \
# 0                  2                0                    3             0  ...
# 1                  4                1                    3             1  ...
# 2                  2                0                    2             1  ...
# 3                  2                1                    4             0  ...
# 4                  0                0                    4             1  ...
#
#    checkout_abandonments_per_month  purchase_conversion_rate  \
# 0                                2                        62
# 1                                7                        54
# 2                                3                        33
# 3                                9                        26
# 4                                0                        18
#
#    app_usage_frequency  notification_response_rate  account_age_months  \
# 0                    7                          74                  19
# 1                    5                          23                   8
# 2                    7                          12                  13
# 3                    4                          19                   9
# 4                    7                          30                   3
#
#    last_purchase_date  social_sharing_frequency  premium_subscription  \
# 0                 172                         6                     1
# 1                 570                         3                     0
# 2                 421                         6                     0
# 3                 664                         7                     0
# 4                 538                         3                     0
#
#    return_rate  churn
# 0           50      0
# 1           37      0
# 2           53      0
# 3           98      0
# 4           86      0
#
# [5 rows x 61 columns]

# %%
plt.figure(figsize=(38, 38))
sns.heatmap(df.corr().abs(), annot = True, cmap ='coolwarm');

# %%
df1 = pd.read_csv("ds2.csv")

# %%
df1.head()
# Out:
#    user_id  age  gender  country urban_rural  income_level employment_status  \
# 0        1   56  Female  Germany    Suburban         90860     Self-employed
# 1        2   69    Male    Japan    Suburban         35423        Unemployed
# 2        3   46  Female    India       Urban         21467     Self-employed
# 3        4   32    Male   Canada       Urban         41770     Self-employed
# 4        5   60  Female    Japan       Urban        183882          Employed
#
#     education_level relationship_status  has_children  ...  \
# 0  Associate Degree              Single             0  ...
# 1          Bachelor              Single             1  ...
# 2  Associate Degree             Married             1  ...
# 3          Bachelor             Widowed             0  ...
# 4  Associate Degree             Widowed             1  ...
#
#    cart_items_average checkout_abandonments_per_month  \
# 0                  10                               2
# 1                   5                               7
# 2                   3                               3
# 3                   5                               9
# 4                   8                               0
#
#   purchase_conversion_rate app_usage_frequency notification_response_rate  \
# 0                       62                   7                         74
# 1                       54                   5                         23
# 2                       33                   7                         12
# 3                       26                   4                         19
# 4                       18                   7                         30
#
#    account_age_months  last_purchase_date  social_sharing_frequency  \
# 0                  19          2025-06-22                         6
# 1                   8          2026-07-25                         3
# 2                  13          2026-02-26                         6
# 3                   9          2026-10-27                         7
# 4                   3          2026-06-23                         3
#
#    premium_subscription  return_rate
# 0                     1           50
# 1                     0           37
# 2                     0           53
# 3                     0           98
# 4                     0           86
#
# [5 rows x 60 columns]

# %%
df1['churn'] = [1 if value < 1 else 0 for value in df1['return_frequency']]

# %%
df1.head()
# Out:
#    user_id  age  gender  country urban_rural  income_level employment_status  \
# 0        1   56  Female  Germany    Suburban         90860     Self-employed
# 1        2   69    Male    Japan    Suburban         35423        Unemployed
# 2        3   46  Female    India       Urban         21467     Self-employed
# 3        4   32    Male   Canada       Urban         41770     Self-employed
# 4        5   60  Female    Japan       Urban        183882          Employed
#
#     education_level relationship_status  has_children  ...  \
# 0  Associate Degree              Single             0  ...
# 1          Bachelor              Single             1  ...
# 2  Associate Degree             Married             1  ...
# 3          Bachelor             Widowed             0  ...
# 4  Associate Degree             Widowed             1  ...
#
#    checkout_abandonments_per_month purchase_conversion_rate  \
# 0                                2                       62
# 1                                7                       54
# 2                                3                       33
# 3                                9                       26
# 4                                0                       18
#
#   app_usage_frequency notification_response_rate account_age_months  \
# 0                   7                         74                 19
# 1                   5                         23                  8
# 2                   7                         12                 13
# 3                   4                         19                  9
# 4                   7                         30                  3
#
#    last_purchase_date  social_sharing_frequency  premium_subscription  \
# 0          2025-06-22                         6                     1
# 1          2026-07-25                         3                     0
# 2          2026-02-26                         6                     0
# 3          2026-10-27                         7                     0
# 4          2026-06-23                         3                     0
#
#    return_rate  churn
# 0           50      0
# 1           37      0
# 2           53      0
# 3           98      0
# 4           86      0
#
# [5 rows x 61 columns]

# %%
#dropping all numerical columns AND last_purchase_date AND user_id
cat_split = df1.drop(columns = ['user_id', 'age', 'income_level', 'household_size', 'weekly_purchases' , 'monthly_spend' , 'cart_abandonment_rate' , 
                                'review_writing_frequency' , 'average_order_value' , 'coupon_usage_frequency' , 'referral_count' , 'impulse_purchases_per_month' , 
                                'browse_to_buy_ratio' , 'return_frequency' , 'brand_loyalty_score' , 'impulse_buying_score' , 'environmental_consciousness' , 
                                'travel_frequency' , 'hobby_count', 'social_media_influence_score' ,'reading_habits' , 'exercise_frequency' , 
                                'stress_from_financial_decisions' , 'overall_stress_level' , 'sleep_quality' , 'physical_activity_level' , 
                                'mental_health_score' , 'daily_session_time_minutes' , 'product_views_per_day' , 'ad_views_per_day' , 
                                'ad_clicks_per_day' , 'wishlist_items_count' , 'cart_items_average' , 'checkout_abandonments_per_month' , 'purchase_conversion_rate' , 
                                'app_usage_frequency' , 'notification_response_rate' , 'account_age_months' , 'social_sharing_frequency' ,'last_purchase_date'])

# %%
cat_split.head()
# Out:
#    user_id  gender  country urban_rural employment_status   education_level  \
# 0        1  Female  Germany    Suburban     Self-employed  Associate Degree
# 1        2    Male    Japan    Suburban        Unemployed          Bachelor
# 2        3  Female    India       Urban     Self-employed  Associate Degree
# 3        4    Male   Canada       Urban     Self-employed          Bachelor
# 4        5  Female    Japan       Urban          Employed  Associate Degree
#
#   relationship_status  has_children   occupation ethnicity  ...  \
# 0              Single             0   Healthcare     Other  ...
# 1              Single             1      Finance     Other  ...
# 2             Married             1   Healthcare     Other  ...
# 3             Widowed             0  Engineering  Hispanic  ...
# 4             Widowed             1        Other     Asian  ...
#
#   preferred_payment_method loyalty_program_member product_category_preference  \
# 0                   PayPal                      1                   Groceries
# 1               Google Pay                      1                   Groceries
# 2                   PayPal                      0                      Beauty
# 3              Credit Card                      1                   Groceries
# 4                Apple Pay                      1                   Groceries
#
#    shopping_time_of_day weekend_shopper budgeting_style  \
# 0               Morning               1          Strict
# 1             Afternoon               1           Loose
# 2             Afternoon               0        Moderate
# 3             Afternoon               1        Moderate
# 4               Evening               0           Loose
#
#    health_conscious_shopping premium_subscription  return_rate  churn
# 0                          1                    1           50      0
# 1                          1                    0           37      0
# 2                          1                    0           53      0
# 3                          1                    0           98      0
# 4                          0                    0           86      0
#
# [5 rows x 22 columns]

# %%
cat_split.columns
# Out:
# Index(['gender', 'country', 'urban_rural', 'employment_status',
#        'education_level', 'relationship_status', 'has_children', 'occupation',
#        'ethnicity', 'language_preference', 'device_type',
#        'preferred_payment_method', 'loyalty_program_member',
#        'product_category_preference', 'shopping_time_of_day',
#        'weekend_shopper', 'budgeting_style', 'health_conscious_shopping',
#        'premium_subscription', 'return_rate', 'churn'],
#       dtype='object')

# %%
#run encoder on categorical columns to make them numerical
encoder = LabelEncoder()
for each_col in categorical_cols:
    cat_split[each_col] = encoder.fit_transform(cat_split[each_col])

# %%
plt.figure(figsize=(20, 8))
sns.heatmap(cat_split.corr().abs(), annot = True, cmap ='coolwarm');

# %% [markdown]
# AND

# %%
df2 = pd.read_csv("ds2.csv")

# %%
#drop all cat columns and date and user_id

num_split1 = df2.drop(columns = ['user_id', 'last_purchase_date', 'gender', 'country', 'urban_rural', 'employment_status', 'education_level',
                    'relationship_status', 'has_children', 'occupation', 'ethnicity',
                    'language_preference', 'device_type', 'preferred_payment_method', 
                    'loyalty_program_member', 'product_category_preference', 'shopping_time_of_day', 
                    'weekend_shopper', 'budgeting_style', 'health_conscious_shopping', 'premium_subscription'])

# %%
plt.figure(figsize=(40, 20))
sns.heatmap(num_split1.corr().abs(), annot = True, cmap ='coolwarm');
