# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("e_commerce_shopper_behaviour_and_lifestyle.csv", parse_dates=["last_purchase_date"])

# %%
df.head()
# Out:
#    user_id  age  gender  country urban_rural  income_level employment_status  \
# 0        1   56  Female  Germany    Suburban         90860     Self-employed
# 1        2   69    Male    Japan    Suburban         35423        Unemployed
# 2        3   46  Female    India       Urban         21467     Self-employed
# 3        4   32    Male   Canada       Urban         41770     Self-employed
# 4        5   60  Female    Japan       Urban        183882          Employed
#
#     education_level relationship_status  has_children  ...  \
# 0  Associate Degree              Single             0  ...
# 1          Bachelor              Single             1  ...
# 2  Associate Degree             Married             1  ...
# 3          Bachelor             Widowed             0  ...
# 4  Associate Degree             Widowed             1  ...
#
#    cart_items_average checkout_abandonments_per_month  \
# 0                  10                               2
# ...

# %%
df.shape
# Out:
# (1000000, 60)

# %%
df.describe()
# Out:
#               user_id             age    income_level    has_children  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean    500000.500000       49.003377   104994.565463        0.399426
# min          1.000000       18.000000    10000.000000        0.000000
# 25%     250000.750000       33.000000    57466.000000        0.000000
# 50%     500000.500000       49.000000   105013.000000        0.000000
# 75%     750000.250000       65.000000   152497.000000        1.000000
# max    1000000.000000       80.000000   200000.000000        1.000000
# std     288675.278933       18.193959    54851.476652        0.489781
#
#        household_size  weekly_purchases   monthly_spend  \
# count  1000000.000000    1000000.000000  1000000.000000
# mean         5.505323          9.993011     2498.775654
# min          1.000000          0.000000        0.000000
# 25%          3.000000          5.000000     1249.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['user_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# user_id                            0
# age                                0
# gender                             0
# country                            0
# urban_rural                        0
# income_level                       0
# employment_status                  0
# education_level                    0
# relationship_status                0
# has_children                       0
# household_size                     0
# occupation                         0
# ethnicity                          0
# language_preference                0
# device_type                        0
# weekly_purchases                   0
# monthly_spend                      0
# cart_abandonment_rate              0
# review_writing_frequency           0
# average_order_value                0
# preferred_payment_method           0
# coupon_usage_frequency             0
# loyalty_program_member             0
# referral_count                     0
# product_category_preference        0
# ...

# %%
plt.scatter(df['age'], df['age']);

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 60 columns):
#  #   Column                           Non-Null Count    Dtype
# ---  ------                           --------------    -----
#  0   user_id                          1000000 non-null  int64
#  1   age                              1000000 non-null  int64
#  2   gender                           1000000 non-null  object
#  3   country                          1000000 non-null  object
#  4   urban_rural                      1000000 non-null  object
#  5   income_level                     1000000 non-null  int64
#  6   employment_status                1000000 non-null  object
#  7   education_level                  1000000 non-null  object
#  8   relationship_status              1000000 non-null  object
#  9   has_children                     1000000 non-null  int64
#  10  household_size                   1000000 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['user_id', 'age', 'gender', 'country', 'urban_rural', 'income_level',
#        'employment_status', 'education_level', 'relationship_status',
#        'has_children', 'household_size', 'occupation', 'ethnicity',
#        'language_preference', 'device_type', 'weekly_purchases',
#        'monthly_spend', 'cart_abandonment_rate', 'review_writing_frequency',
#        'average_order_value', 'preferred_payment_method',
#        'coupon_usage_frequency', 'loyalty_program_member', 'referral_count',
#        'product_category_preference', 'shopping_time_of_day',
#        'weekend_shopper', 'impulse_purchases_per_month', 'browse_to_buy_ratio',
#        'return_frequency', 'budgeting_style', 'brand_loyalty_score',
#        'impulse_buying_score', 'environmental_consciousness',
#        'health_conscious_shopping', 'travel_frequency', 'hobby_count',
#        'social_media_influence_score', 'reading_habits', 'exercise_frequency',
# ...

# %%
df['gender'].value_counts()
# Out:
# gender
# Male          480132
# Female        479808
# Non-binary     20223
# Other          19837
# Name: count, dtype: int64

# %%
df['urban_rural'].value_counts()
# Out:
# urban_rural
# Urban       500226
# Suburban    299993
# Rural       199781
# Name: count, dtype: int64

# %%
df['employment_status'].value_counts()
# Out:
# employment_status
# Retired          200246
# Unemployed       200225
# Employed         199988
# Student          199949
# Self-employed    199592
# Name: count, dtype: int64

# %%
df['education_level'].value_counts()
# Out:
# education_level
# Bachelor            299953
# High School         299391
# Associate Degree    200989
# Master              149699
# PhD                  49968
# Name: count, dtype: int64

# %%
df['relationship_status'].value_counts()
# Out:
# relationship_status
# Divorced             200675
# Widowed              200155
# In a relationship    200075
# Married              199844
# Single               199251
# Name: count, dtype: int64

# %%
df['has_children'].value_counts()
# Out:
# has_children
# 0    600574
# 1    399426
# Name: count, dtype: int64

# %%
df['device_type'].value_counts()
# Out:
# device_type
# Mobile     600247
# Desktop    299845
# Tablet      99908
# Name: count, dtype: int64

# %%
df['preferred_payment_method'].value_counts()
# Out:
# preferred_payment_method
# Apple Pay        166983
# Debit Card       166980
# Bank Transfer    166708
# Google Pay       166705
# PayPal           166340
# Credit Card      166284
# Name: count, dtype: int64

# %%
df['shopping_time_of_day'].value_counts()
# Out:
# shopping_time_of_day
# Evening      250185
# Night        250112
# Morning      250097
# Afternoon    249606
# Name: count, dtype: int64

# %%
df['budgeting_style'].value_counts()
# Out:
# budgeting_style
# Moderate    333771
# Loose       333438
# Strict      332791
# Name: count, dtype: int64

# %%
pd.set_option('display.max_columns', None)

# Show the columns 
display(df)
# Out:
#         user_id  age  gender  country urban_rural  income_level  \
# 0             1   56  Female  Germany    Suburban         90860
# 1             2   69    Male    Japan    Suburban         35423
# 2             3   46  Female    India       Urban         21467
# 3             4   32    Male   Canada       Urban         41770
# 4             5   60  Female    Japan       Urban        183882
# ...         ...  ...     ...      ...         ...           ...
# 999995   999996   36  Female   France       Urban        192880
# 999996   999997   37    Male   Canada       Urban        197111
# 999997   999998   71    Male       UK       Urban        171275
# 999998   999999   30  Female  Germany       Urban        124983
# 999999  1000000   61    Male    China       Rural         65396
#
#        employment_status   education_level relationship_status  has_children  \
# 0          Self-employed  Associate Degree              Single             0
# ...

# %%
df['churn'] = [1 if value < 1 else 0 for value in df['return_frequency']]

# %%
display(df)
# Out:
#         user_id  age  gender  country urban_rural  income_level  \
# 0             1   56  Female  Germany    Suburban         90860
# 1             2   69    Male    Japan    Suburban         35423
# 2             3   46  Female    India       Urban         21467
# 3             4   32    Male   Canada       Urban         41770
# 4             5   60  Female    Japan       Urban        183882
# ...         ...  ...     ...      ...         ...           ...
# 999995   999996   36  Female   France       Urban        192880
# 999996   999997   37    Male   Canada       Urban        197111
# 999997   999998   71    Male       UK       Urban        171275
# 999998   999999   30  Female  Germany       Urban        124983
# 999999  1000000   61    Male    China       Rural         65396
#
#        employment_status   education_level relationship_status  has_children  \
# 0          Self-employed  Associate Degree              Single             0
# ...

# %%
df['churn'].value_counts()
# Out:
# churn
# 0    923197
# 1     76803
# Name: count, dtype: int64

# %%
sns.countplot(df, x='churn');

# %%
def ordered_bar_chart(column_name):
    base_color = sns.color_palette()[0]
    x = df[column_name].value_counts().index
    y = df[column_name].value_counts()

    plt.figure(figsize=(10, 5))
    plt.bar(x=x, height=y)
    plt.xticks(rotation=45);

# %%
ordered_bar_chart('language_preference')

# %%
categorical_cols = ['gender', 'country', 'urban_rural', 'employment_status', 'education_level',
                    'relationship_status', 'has_children', 'occupation', 'ethnicity',
                    'language_preference', 'device_type', 'preferred_payment_method', 
                    'loyalty_program_member', 'product_category_preference', 'shopping_time_of_day', 
                    'weekend_shopper', 'budgeting_style', 'health_conscious_shopping', 'premium_subscription']

# %%
for col in categorical_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
plt.hist(df['age']);

# %%
df.to_parquet('df_cleaned2.parquet', index=False)

# %%
_ = df.hist(figsize=(20, 14))

# %%
fig, axes = plt.subplots(10, 2, figsize=[50, 50])
axes = axes.flatten()
index = 0
#fig.tight_layout(pad=7.0)
#plt.rcParams["font.size"] = 25

for i in range(19):
    g = sns.countplot(data=df, hue='churn', x=categorical_cols[index], palette = 'Blues', ax=axes[i])
    g.tick_params(axis='x', labelrotation = 45)
    g.legend(loc = 1); # re-arrange legend to remove overlapping
    index += 1

# %%
plt.figure(figsize=(38, 8))
sns.heatmap(df.corr().abs(), annot = True, cmap ='coolwarm');

# %%
df.describe(exclude= ['O']) # Describe all numerical columns
df.describe(include = ['O']) # Describe all categorical columns

# %%
plt.clf()

# %%
df
